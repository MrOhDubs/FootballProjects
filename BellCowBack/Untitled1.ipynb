# %%
library(rvest)
library(tidyverse)

# %%
rushing_player <- data.frame()

for (i in 2014:2018){
    url <- paste0('https://www.pro-football-reference.com/years/', i, '/rushing.htm')
    page <- read_html(url)
    rank_data <- html_nodes(page, '#rushing')
    dat <- as.data.frame(html_table(rank_data))
    colnames(dat) <- dat[1,]
    dat <- dat[-1,]
    dat %>% filter(Tm != 'Tm') -> dat
    dat$year <- i
    dat$Player <- gsub('\\*?\\+?', '', dat$Player)
    
    rushing_player <- rbind(rushing_player, dat)
}

write.csv(rushing_player, file = 'Data/rushing_player.csv', row.names = F)

rushing_player <- read.csv(file  = 'Data/rushing_player.csv')
head(rushing_player)
# Out:
#   Rk Player         Tm  Age Pos G  GS Att Yds  TD Lng Y.A Y.G   Fmb year
# 1 1  DeMarco Murray DAL 26  RB  16 16 392 1845 13 51  4.7 115.3 6   2014
# 2 2  LeSean McCoy   PHI 26  RB  16 16 312 1319  5 53  4.2  82.4 4   2014
# 3 3  Le'Veon Bell   PIT 22  RB  16 16 290 1361  8 81  4.7  85.1 0   2014
# 4 4  Marshawn Lynch SEA 28  RB  16 14 280 1306 13 79  4.7  81.6 4   2014
# 5 5  Matt Forte     CHI 29  RB  16 16 266 1038  6 32  3.9  64.9 2   2014
# 6 6  Alfred Morris  WAS 26  RB  16 16 265 1074  8 30  4.1  67.1 2   2014

# %% [markdown]
# Now we want to make sure we are only looking at the leading rushers for each team in a given year.

# %%
rushing_player %>%
    group_by(Tm, year) %>%
    top_n(n = 1, wt = as.numeric(Yds)) -> top_rushers

# %%
rushing_team <- data.frame()

for (i in 2014:2018) {
    url <- paste0('https://www.pro-football-reference.com/years/', i, '/')

    url %>% read_html() %>%               # parse html
    html_nodes('#all_rushing') %>%        # select node with comment
    html_nodes(xpath = 'comment()') %>%   # select comments within node
    html_text() %>%                       # return contents as text
    read_html() %>%                       # parse text as html
    html_node('table') %>%                # select table node
    html_table() -> dat
    dat <- dat[-seq(nrow(dat)-2,nrow(dat)),]
    dat$year <- i
    
    rushing_team <- rbind(rushing_team, dat)
  }  
write.csv(rushing_team, file = 'Data/rushing_team.csv', row.names = F)
rushing_team <- read.csv(file = 'Data/rushing_team.csv')
head(rushing_team)
# Out:
#   Rk Tm                  G  Att Yds  TD Lng Y.A Y.G   Fmb EXP    year
# 1 1  Seattle Seahawks    16 525 2762 20 79  5.3 172.6 23   65.66 2014
# 2 2  Dallas Cowboys      16 508 2354 16 65  4.6 147.1 21  -17.90 2014
# 3 3  New York Jets       16 507 2280 11 71  4.5 142.5 25  -19.76 2014
# 4 4  San Francisco 49ers 16 470 2176 10 90  4.6 136.0 18  -32.96 2014
# 5 5  Houston Texans      16 551 2161 12 51  3.9 135.1 19  -44.90 2014
# 6 6  Cincinnati Bengals  16 492 2147 19 89  4.4 134.2 20    3.67 2014

# %%
ref <- read.csv('C:\\Users\\osnwh2\\PyProjects\\TeamAbbrev.csv')[,-1]
colnames(ref) <- c('Team', 'Tm', 'Conference', 'Division')

# %%
rushing_player <- merge(top_rushers, ref)

# %%
head(rushing_player)
# Out:
#   Tm  Rk Player           Age Pos G  GS Att Yds  TD Lng Y.A Y.G  Fmb year
# 1 ARI  3 David Johnson    27  RB  16 16 258  940  7 53  3.6 58.8 3   2018
# 2 ARI 39 Kerwynn Williams 26  rb  16  6 120  426  1 25  3.6 26.6 0   2017
# 3 ARI  3 David Johnson    25  RB  16 16 293 1239 16 58  4.2 77.4 5   2016
# 4 ARI 16 Chris Johnson    30  RB  11  9 196  814  3 62  4.2 74.0 2   2015
# 5 ARI 17 Andre Ellington  25  RB  12 12 201  660  3 22  3.3 55.0 2   2014
# 6 ATL  4 Devonta Freeman  23  RB  15 13 265 1056 11 39  4.0 70.4 3   2015
#   Team              Conference Division
# 1 Arizona Cardinals NFC        West
# 2 Arizona Cardinals NFC        West
# 3 Arizona Cardinals NFC        West
# 4 Arizona Cardinals NFC        West
# 5 Arizona Cardinals NFC        West
# 6 Atlanta Falcons   NFC        South

# %%
rushing_player %>%
select(year, Tm, Team, Player, Age, Pos, G, Att, Yds, TD, Fmb, Conference, Division) -> rushing_player

# %%
rushing_team %>%
select(Tm, Yds, Att, TD, Fmb, year) %>%
merge(rushing_player, by.x = c('Tm', 'year'), by.y = c('Team', 'year')) -> rushing
colnames(rushing) <- c('Team', 'Year', 'TeamYds', 'TeamAtt','TeamTD','TeamFmb','Abbv','Player','Age','Pos','G','PlayerAtt','PlayerYds','PlayerTD','PlayerFmb','Conference','Division')

# %%
rushing
# Out:
#     Team                Year TeamYds TeamAtt TeamTD TeamFmb Abbv
# 1   Arizona Cardinals   2014 1308    397      6     16      ARI
# 2   Arizona Cardinals   2015 1917    452     16     23      ARI
# 3   Arizona Cardinals   2016 1732    399     20     27      ARI
# 4   Arizona Cardinals   2017 1386    410      6     19      ARI
# 5   Arizona Cardinals   2018 1342    355      9     23      ARI
# 6   Atlanta Falcons     2014 1498    372     11     16      ATL
# 7   Atlanta Falcons     2015 1606    420     13     26      ATL
# 8   Atlanta Falcons     2016 1928    421     20      8      ATL
# 9   Atlanta Falcons     2017 1847    430     12     17      ATL
# 10  Atlanta Falcons     2018 1573    351     11     24      ATL
# 11  Baltimore Ravens    2014 2019    448     16     16      BAL
# 12  Baltimore Ravens    2015 1478    383      8     13      BAL
# 13  Baltimore Ravens    2016 1463    367     10     19      BAL
# 14  Baltimore Ravens    2017 1856    460     14     19      BAL
# 15  Baltimore Ravens    2018 2441    547     19     25      BAL
# 16  Buffalo Bills       2014 1482    402      7     22      BUF
# 17  Buffalo Bills       2015 2432    509     19     28      BUF
# 18  Buffalo Bills       2016 2630    492     29     15      BUF
# 19  Buffalo Bills       2017 2017    487     12     17      BUF
# 20  Buffalo Bills       2018 1984    468     15     23      BUF
# 21  Carolina Panthers   2014 2036    473     10     25      CAR
# 22  Carolina Panthers   2015 2282    526     19     12      CAR
# 23  Carolina Panthers   2016 1814    453     16     13      CAR
# 24  Carolina Panthers   2017 2102    490     15     19      CAR
# 25  Carolina Panthers   2018 2136    416     17     20      CAR
# 26  Chicago Bears       2014 1441    355      8     19      CHI
# 27  Chicago Bears       2015 1854    468     13     20      CHI
# 28  Chicago Bears       2016 1735    380     10     26      CHI
# 29  Chicago Bears       2017 1788    422     13     24      CHI
# 30  Chicago Bears       2018 1938    468     16     23      CHI
# ... ...                 ...  ...     ...     ...    ...     ...
# 83  Oakland Raiders     2016 1922    434     17     17      OAK
# 84  Oakland Raiders     2017 1554    370     13     33      OAK
# 85  Oakland Raiders     2018 1628    387      9     24      OAK
# 86  Philadelphia Eagles 2014 1992    474     16     25      PHI
# ... ...                 ... ... ... ...       ...       ...      ...
# 83  Latavius Murray     26  RB  14  195        788      12        2
# 84  Marshawn Lynch      31  RB  15  207        891       7        1
# 85  Doug Martin         29  RB  16  172        723       4        3
# 86  LeSean McCoy        26  RB  16  312       1319       5        4
# 87  DeMarco Murray      27  RB  15  193        702       6        2
# 88  Ryan Mathews        29  RB  13  155        661       8        3
# 89  LeGarrette Blount   31  RB  16  173        766       2        1
# 90  Josh Adams          22  rb  14  120        511       3        1
# 91  Le'Veon Bell        22  RB  16  290       1361       8        0
# 92  DeAngelo Williams   32  RB  16  200        907      11        4
# 93  Le'Veon Bell        24  RB  12  261       1268       7        4
# 94  Le'Veon Bell        25  RB  15  321       1291       9        3
# 95  James Conner        23  RB  13  215        973      12        4
# 96  Marshawn Lynch      28  RB  16  280       1306      13        4
# 97  Thomas Rawls        22  rb  13  147        830       4        1
# 98  Thomas Rawls        23  rb   9  109        349       3        0
# 99  Russell Wilson      29  QB  16   95        586       3       14
# 100 Chris Carson        24  RB  14  247       1151       9        3
# 101 Tre Mason           21  RB  12  179        765       4        2
# 102 Todd Gurley         21  RB  13  229       1106      10        3
# 103 Bishop Sankey       22  RB  16  152        569       2        2
# 104 Antonio Andrews     23  RB  14  143        520       3        1
# 105 DeMarco Murray      28  RB  16  293       1287       9        3
# 106 Derrick Henry       23  rb  16  176        744       5        1
# 107 Derrick Henry       24  RB  16  215       1059      12        1
# 108 Alfred Morris       26  RB  16  265       1074       8        2
# 109 Alfred Morris       27  RB  16  202        751       1        0
# 110 Robert Kelley       24  RB  15  168        704       6        0
# 111 Samaje Perine       22  RB  16  175        603       1        2
# 112 Adrian Peterson     33  RB  16  251       1042       7        3
#     Conference Division
# 1   NFC        West
# 2   NFC        West
# 3   NFC        West
# 4   NFC        West
# 5   NFC        West
# 6   NFC        South
# 7   NFC        South
# 8   NFC        South
# 9   NFC        South
# 10  NFC        South
# 11  AFC        North
# 12  AFC        North
# 13  AFC        North
# 14  AFC        North
# 15  AFC        North
# 16  AFC        East
# 17  AFC        East
# 18  AFC        East
# 19  AFC        East
# 20  AFC        East
# 21  NFC        South
# 22  NFC        South
# 23  NFC        South
# 24  NFC        South
# 25  NFC        South
# 26  NFC        North
# 27  NFC        North
# 28  NFC        North
# 29  NFC        North
# 30  NFC        North
# ... ...        ...
# 83  AFC        West
# 84  AFC        West
# 85  AFC        West
# 86  NFC        East
# 87  NFC        East
# 88  NFC        East
# 89  NFC        East
# 90  NFC        East
# 91  AFC        North
# 92  AFC        North
# 93  AFC        North
# 94  AFC        North
# 95  AFC        North
# 96  NFC        West
# 97  NFC        West
# 98  NFC        West
# 99  NFC        West
# 100 NFC        West
# 101 NFC        West
# 102 NFC        West
# 103 AFC        South
# 104 AFC        South
# 105 AFC        South
# 106 AFC        South
# 107 AFC        South
# 108 NFC        East
# 109 NFC        East
# 110 NFC        East
# 111 NFC        East
# 112 NFC        East

# %%
merge(top_rushers, rev, by.x = 'Tm', by.y = 'Abbreviation')
# Out:
# Error in if (nx >= 2^31 || ny >= 2^31) stop("long vectors are not supported"): missing value where TRUE/FALSE needed
# Traceback:
#
# 1. merge(top_rushers, rev, by.x = "Tm", by.y = "Abbreviation")
# 2. merge.data.frame(top_rushers, rev, by.x = "Tm", by.y = "Abbreviation")
